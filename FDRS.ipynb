# %%
import cv2
import sys
import serial

# %%
faceCascade = cv2.CascadeClassifier('faceCascade.xml')

url = 'http://192.168.0.5:8080/shot.jpg' #aqui se debe ingresar la url que da la aplicación para enlazarla a la camara del telefono
cap = cv2.VideoCapture(url)

serialArduino = serial.Serial("COM4",9600)

# %%
if cap.isOpened():
    print("Ip Cam initializatized")
else:
    print("Ip Cam disconnected")
    sys.exit(1)

winName = 'IP_CAM'
cv2.namedWindow(winName, cv2.WINDOW_AUTOSIZE)
# Out:
# Ip Cam initializatized

# %%
while True:

    cap.open(url)
    ret, frame = cap.read()

    if ret:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = faceCascade.detectMultiScale(gray,scaleFactor=1.3,minNeighbors=5)
        
        for (x,y,w,h) in faces:
            cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
            print(x-255,y-255,x+w-255,y+h-255)
            
            if(y-255 > -20):
                print("moviendo hacia adelante")
                cad = 'u'
                serialArduino.write(cad.encode('ascii'))
            else:
                if(y-255 < -100):
                    print("moviendo hacia atras")
                    cad = 'd'
                    serialArduino.write(cad.encode('ascii'))
            if(x-255 < -125):
                print("moviendo hacia la derecha")
                cad = 'r'
                serialArduino.write(cad.encode('ascii'))
            else:
                if(x-255 > 125):
                    print("moviendo hacia la izquierda")
                    cad = 'l'
                    serialArduino.write(cad.encode('ascii'))
        cv2.circle(frame,(int(frame.shape[1]/2),int(frame.shape[0]/2)),20, (0,0,255),3)
        cv2.imshow(winName,frame)
    else:
        print("Ip Cam disconnected")
        break

    if (cv2.waitKey(10) & 0xFF == 27):
        break
# Out:
# 49 -235 261 -23
# moviendo hacia atras
# 46 -228 240 -34
# moviendo hacia atras
# 17 -209 194 -32
# moviendo hacia atras
# 3 -177 152 -28
# moviendo hacia atras
# 5 -155 153 -7
# moviendo hacia atras
# 5 -140 159 14
# moviendo hacia atras
# 17 -118 169 34
# moviendo hacia atras
# 20 -118 183 45
# moviendo hacia atras
# -1 -112 158 47
# moviendo hacia atras
# -16 -110 142 48
# moviendo hacia atras
# -35 -134 153 54
# moviendo hacia atras
# -14 -110 149 53
# moviendo hacia atras
# -21 -119 153 55
# moviendo hacia atras
# -27 -119 141 49
# moviendo hacia atras
# -33 -112 134 55
# moviendo hacia atras
# -28 -111 142 59
# moviendo hacia atras
# -33 -109 137 61
# moviendo hacia atras
# -33 -112 141 62
# moviendo hacia atras
# -23 -118 154 59
# moviendo hacia atras
# -20 -122 157 55
# moviendo hacia atras
# -14 -102 154 66
# moviendo hacia atras
# -25 -101 147 71
# moviendo hacia atras
# -47 -108 132 71
# moviendo hacia atras
# -21 -111 153 63
# moviendo hacia atras
# -18 -117 164 65
# moviendo hacia atras
# -33 -123 174 84
# moviendo hacia atras
# -35 -124 175 86
# moviendo hacia atras
# -28 -111 169 86
# moviendo hacia atras
# -22 -103 161 80
# moviendo hacia atras
# -24 -106 162 80
# moviendo hacia atras
# -20 -102 164 82
# moviendo hacia atras
# -16 -112 181 85
# moviendo hacia atras
# -20 -109 179 90
# moviendo hacia atras
# -11 -105 172 78
# moviendo hacia atras
# -17 -110 179 86
# moviendo hacia atras
# 5 -104 182 73
# moviendo hacia atras
# -7 -107 175 75
# moviendo hacia atras
# -4 -107 177 74
# moviendo hacia atras
# -15 -111 184 88
# moviendo hacia atras
# -3 -107 181 77
# moviendo hacia atras
# -3 -103 180 80
# moviendo hacia atras
# -8 -89 176 95
# -9 -50 185 144
# -53 -1 139 191
# moviendo hacia adelante
# -55 -63 147 139
# -48 -86 148 110
# -46 -98 150 98
# -43 -116 146 73
# moviendo hacia atras
# -64 -188 148 24
# moviendo hacia atras
# -71 -221 148 -2
# moviendo hacia atras
# -62 -221 141 -18
# moviendo hacia atras
# -66 -218 148 -4
# moviendo hacia atras
# -75 -194 126 7
# moviendo hacia atras
# -108 -115 96 89
# moviendo hacia atras
# -160 -107 52 105
# moviendo hacia atras
# moviendo hacia la derecha
# -211 -80 -6 125
# moviendo hacia la derecha
# -194 -82 8 120
# moviendo hacia la derecha
# -201 -102 34 133
# moviendo hacia atras
# moviendo hacia la derecha
# -156 -94 47 109
# moviendo hacia la derecha
# -101 -99 94 96
# -63 -91 126 98
# -59 -97 145 107
# -9 -85 191 115
# 23 -63 229 143
# 42 -51 251 158
# 46 -55 269 168
# 75 -44 287 168
# 89 -42 307 176
# 89 -47 316 180
# 83 -46 321 192
# -25 -101 200 124
# moviendo hacia atras
# -7 -90 198 115
# -9 -87 197 119
# -17 -88 206 135
# -16 -89 207 134
# -17 -91 216 142
# 8 -69 198 121
# 0 -77 200 123
# 0 -75 197 122
# -12 -80 210 142
# -11 -73 211 149
# -13 -75 215 153
# -13 -73 215 155
# -7 -68 207 146
# 0 -63 203 140
# -8 -67 205 146
# -5 -66 209 148
# 1 -60 199 138
# -3 -61 200 142
# 0 -60 202 142
# -5 -67 209 147
# -7 -70 212 149
# -3 -65 209 147
# -3 -65 205 143
# -2 -64 207 145
# -4 -67 208 145
# -2 -65 205 142
# -1 -66 206 141
# 3 -62 205 140
# -3 -75 206 134
# -8 -80 211 139
# -3 -76 204 131
# 4 -72 202 126
# 1 -83 216 132
# 4 -83 213 126
# 6 -85 221 130
# 14 -78 218 126
# 14 -77 218 127
# 7 -84 228 137
# 14 -82 221 125
# 24 -87 230 119
# 14 -104 249 131
# moviendo hacia atras
# 1 -117 236 118
# moviendo hacia atras
# -18 -121 228 125
# moviendo hacia atras
# -15 -118 226 123
# moviendo hacia atras
# -1 -113 222 110
# moviendo hacia atras
# 7 -104 228 117
# moviendo hacia atras
# 0 -103 231 128
# moviendo hacia atras
# 0 -107 239 132
# moviendo hacia atras
# 9 -102 229 118
# moviendo hacia atras
# 7 -102 235 126
# moviendo hacia atras
# 8 -104 243 131
# moviendo hacia atras
# 7 -105 244 132
# moviendo hacia atras
# 5 -107 244 132
# moviendo hacia atras
# 6 -103 239 130
# moviendo hacia atras
# 10 -97 243 136
# 13 -93 244 138
# 19 -88 252 145
# 22 -85 250 143
# 20 -86 250 144
# 20 -86 252 146
# 21 -85 244 138
# 12 -89 237 136
# 2 -97 216 117
# -13 -101 206 118
# moviendo hacia atras
# -11 -101 201 111
# moviendo hacia atras
# -13 -102 213 124
# moviendo hacia atras
# -8 -101 217 124
# moviendo hacia atras
# -7 -95 212 124
# -17 -104 218 131
# moviendo hacia atras
# -12 -103 217 126
# moviendo hacia atras
# -5 -98 215 122
# -3 -94 216 125
# 1 -91 212 120
# -5 -97 219 127
# -6 -97 219 128
# -5 -97 219 127
# -3 -100 227 130
# -5 -98 223 130
# -4 -99 223 128
# -4 -99 231 136
# 0 -88 231 143
# 4 -88 228 136
# 4 -83 232 145
# 16 -80 235 139
# 18 -79 243 146
# 28 -78 247 141
# 39 -74 245 132
# 38 -79 244 127
# 37 -78 243 128
# 42 -75 247 130
# 55 -72 249 122
# 39 -76 245 130
# 50 -69 244 125
# 45 -70 243 128
# 50 -70 246 126
# 38 -76 242 128
# 34 -75 246 137
# 38 -78 252 136
# 40 -74 247 133
# 38 -75 250 137
# 36 -79 260 145
# 40 -75 252 137
# 42 -72 249 135
# 44 -67 248 137
# 45 -67 249 137
# 34 -76 255 145
# 39 -69 251 143
# 47 -71 259 141
# 45 -71 257 141
# 51 -70 269 148
# 49 -73 274 152
# 68 -61 276 147
# 60 -63 280 157
# 65 -55 277 157
# 61 -75 319 183
# 76 -186 341 79
# moviendo hacia atras
# 74 -174 326 78
# moviendo hacia atras
# 66 -155 299 78
# moviendo hacia atras
# 54 -151 282 77
# moviendo hacia atras
# -16 -128 156 44
# moviendo hacia atras
# -11 -120 149 40
# moviendo hacia atras
# 1 -121 156 34
# moviendo hacia atras
# -29 -99 126 56
# -22 -95 119 46
# -32 -98 123 57
# -38 -91 119 66
# -42 -86 116 72
# -44 -88 114 70
# -45 -86 106 65
# -47 -86 104 65
# -57 -90 100 67
# -74 -96 86 64
# -71 -90 81 62
# -78 -88 78 68
# -83 -85 72 70
# -98 -90 70 78
# -96 -84 61 73
# -100 -88 62 74
# -99 -84 55 70
# -112 -88 49 73
# -115 -86 41 70
# -127 -85 32 74
# moviendo hacia la derecha
# -135 -79 20 76
# moviendo hacia la derecha
# -150 -84 14 80
# moviendo hacia la derecha
# -163 -85 8 86
# moviendo hacia la derecha
# -173 -84 -4 85
# moviendo hacia la derecha
# -194 -83 -23 88
# moviendo hacia la derecha
# -190 -77 -30 83
# moviendo hacia la derecha
# -186 -75 -17 94
# moviendo hacia la derecha
# -172 -71 -9 92
# moviendo hacia la derecha
# -160 -67 -4 89
# moviendo hacia la derecha
# -157 -69 8 96
# moviendo hacia la derecha
# -146 -70 24 100
# moviendo hacia la derecha
# -125 -70 41 96
# -106 -66 54 94
# -88 -63 67 92
# -80 -65 77 92
# -75 -71 87 91
# -73 -71 88 90
# -66 -70 96 92
# -50 -78 121 93
# -47 -42 140 145
# -49 -43 131 137
# -56 -45 128 139
# -59 -43 121 137
# -63 -48 127 142
# -62 -40 124 146
# -56 -32 125 149
# -54 -34 124 144
# -55 -32 124 147
# -64 5 148 217
# moviendo hacia adelante
# -63 -4 149 208
# moviendo hacia adelante
# -66 -11 152 207
# moviendo hacia adelante
# -62 -16 157 203
# moviendo hacia adelante
# -57 -20 161 198
# -69 -24 145 190
# -81 -49 147 179
# -66 -43 136 159
# -62 -58 142 146
# -49 -65 132 116
# -53 -71 127 109
# -54 -76 127 105
# -51 -70 130 111
# -50 -40 124 134
# -47 -23 121 145
# -26 9 129 164
# moviendo hacia adelante
# -27 19 144 190
# moviendo hacia adelante
# -27 43 136 206
# moviendo hacia adelante
# -30 58 133 221
# moviendo hacia adelante
# -31 59 132 222
# moviendo hacia adelante
# -32 39 135 206
# moviendo hacia adelante
# -35 31 133 199
# moviendo hacia adelante
# -41 27 129 197
# moviendo hacia adelante
# -41 16 129 186
# moviendo hacia adelante
# -41 1 130 172
# moviendo hacia adelante
# -50 -26 131 155
# -47 -47 121 121
# -57 -74 119 102
# -60 -106 117 71
# moviendo hacia atras
# -53 -136 124 41
# moviendo hacia atras
# -45 -154 132 23
# moviendo hacia atras
# -35 -165 137 7
# moviendo hacia atras
# -42 -177 131 -4
# moviendo hacia atras
# -46 -178 128 -4
# moviendo hacia atras
# -39 -177 126 -12
# moviendo hacia atras
# -43 -187 131 -13
# moviendo hacia atras
# -40 -193 134 -19
# moviendo hacia atras
# -51 -210 133 -26
# moviendo hacia atras
# -52 -222 128 -42
# moviendo hacia atras
# -52 -234 129 -53
# moviendo hacia atras
# -51 -239 122 -66
# moviendo hacia atras
# -52 -242 122 -68
# moviendo hacia atras
# -41 -238 109 -88
# moviendo hacia atras
# -58 -244 123 -63
# moviendo hacia atras
# -56 -233 122 -55
# moviendo hacia atras
# -53 -203 126 -24
# moviendo hacia atras
# -45 -177 131 -1
# moviendo hacia atras
# -45 -141 128 32
# moviendo hacia atras
# -49 -119 121 51
# moviendo hacia atras
# -42 -100 132 74
# -12 -93 164 83
# 61 -91 237 85
# 96 -87 269 86
# 90 -84 271 97
# 82 -87 266 97
# 86 -83 263 94
# 90 -89 275 96
# 104 -85 278 89
# 104 -88 282 90
# 101 -83 271 87
# 89 -90 273 94
# 96 -91 275 88
# 95 -90 278 93
# 102 -84 270 84
# 102 -89 281 90
# 107 -91 287 89
# 113 -100 301 88
# 119 -96 303 88
# 130 -94 301 77
# moviendo hacia la izquierda
# 132 -99 312 81
# moviendo hacia la izquierda
# 129 -103 318 86
# moviendo hacia atras
# moviendo hacia la izquierda
# 134 -104 319 81
# moviendo hacia atras
# moviendo hacia la izquierda
# 138 -98 319 83
# moviendo hacia la izquierda
# 153 -89 312 70
# moviendo hacia la izquierda
# 153 -91 330 86
# moviendo hacia la izquierda
# 162 -92 347 93
# moviendo hacia la izquierda
# 167 -100 363 96
# moviendo hacia la izquierda
# 186 -90 368 92
# moviendo hacia la izquierda
# 174 -92 372 106
# moviendo hacia la izquierda
# 149 -88 343 106
# moviendo hacia la izquierda
# 119 -90 316 107
# 115 -89 305 101
# 112 -90 304 102
# 106 -89 295 100
# 104 -88 285 93
# 85 -89 273 99
# 61 -88 247 98
# -17 -92 162 87
# -106 -116 113 103
# moviendo hacia atras
# -142 -111 65 96
# moviendo hacia atras
# moviendo hacia la derecha
# -158 -103 36 91
# moviendo hacia atras
# moviendo hacia la derecha
# -180 -108 16 88
# moviendo hacia atras
# moviendo hacia la derecha
# -182 -104 10 88
# moviendo hacia atras
# moviendo hacia la derecha
# -129 -99 60 90
# moviendo hacia la derecha
# -116 -97 69 88
# -135 -102 61 94
# moviendo hacia atras
# moviendo hacia la derecha
# -137 -102 54 89
# moviendo hacia atras
# moviendo hacia la derecha
# -138 -100 52 90
# moviendo hacia la derecha
# -145 -98 39 86
# moviendo hacia la derecha
# -156 -104 38 90
# moviendo hacia atras
# moviendo hacia la derecha
# -178 -102 11 87
# moviendo hacia atras
# moviendo hacia la derecha
# -189 -101 0 88
# moviendo hacia atras
# moviendo hacia la derecha
# -206 -104 -14 88
# moviendo hacia atras
# moviendo hacia la derecha
# -204 -105 -2 97
# moviendo hacia atras
# moviendo hacia la derecha
# -199 -106 2 95
# moviendo hacia atras
# moviendo hacia la derecha
# -194 -104 0 90
# moviendo hacia atras
# moviendo hacia la derecha
# -191 -99 -5 87
# moviendo hacia la derecha
# -195 -101 -4 90
# moviendo hacia atras
# moviendo hacia la derecha
# -191 -104 5 92
# moviendo hacia atras
# moviendo hacia la derecha
# -207 -103 -14 90
# moviendo hacia atras
# moviendo hacia la derecha
# -227 -110 -20 97
# moviendo hacia atras
# moviendo hacia la derecha
# -232 -107 -26 99
# moviendo hacia atras
# moviendo hacia la derecha
# -231 -105 -35 91
# moviendo hacia atras
# moviendo hacia la derecha
# -218 -107 -17 94
# moviendo hacia atras
# moviendo hacia la derecha
# -194 -104 2 92
# moviendo hacia atras
# moviendo hacia la derecha
# -177 -103 23 97
# moviendo hacia atras
# moviendo hacia la derecha
# -161 -102 29 88
# moviendo hacia atras
# moviendo hacia la derecha
# -147 -107 45 85
# moviendo hacia atras
# moviendo hacia la derecha
# -126 -107 60 79
# moviendo hacia atras
# moviendo hacia la derecha
# -87 -115 96 68
# moviendo hacia atras
# -31 -119 159 71
# moviendo hacia atras
# -8 -119 173 62
# moviendo hacia atras
# -4 -132 202 74
# moviendo hacia atras
# 12 -127 196 57
# moviendo hacia atras
# 15 -121 192 56
# moviendo hacia atras
# -16 -129 197 84
# moviendo hacia atras
# -41 -107 138 72
# moviendo hacia atras

# %%
cap.release()
cv2.destroyAllWindows()
